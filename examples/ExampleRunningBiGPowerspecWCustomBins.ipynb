# %%
import matplotlib.pyplot as plt
import numpy as np
from helpers_plot import initPlot, finalizePlot # For pretty plots

# %%
# pip install ../

# %% [markdown]
# # Example Running BiG for powerspectrum with custom $k$s
#
# This notebook runs the Powerspectrum estimator with custom k-bins

# %% [markdown]
# ## Run BiG

# %% [markdown]
# Measure the powerpectra in example data. The example data can be downloaded here: https://fileshare.uibk.ac.at/d/6e64b19298ac4e9290f3/. Please place it in the current folder (`examples/`)

# %% [markdown]
# The code reads in the file `testRun_input.dat`, which contains the filepaths to all meshs for which the bispectrum shall be calculated. We also set various binning modes and the output filename

# %%
# !python ../scripts/runPowerspectrumExtractor_customKbins.py --L 1000 --Nmesh 128 --kbinFile customKBins_powerspec.dat --outfn ../examples/testRun_p_output --infiles ../examples/testRun_input.dat --verbose True --filetype numpy
# Out:
# Finished reading CMD line arguments
# Settings:
# Boxsize: 1000.0 Mpc/h
# Grid Cells (1D): 128
# Using ks from customKBins_powerspec.dat
# Reading density files from ../examples/testRun_input.dat
# Writing output to ../examples/testRun_p_output
# Finished setting members of bispectrumExtractor
# Creating k-mesh
# Finished initialization BispectrumExtractor
# Doing Powerspec normalization calculation
# Calculating powerspectrum for /home/laila/CodeRepos/BiG/examples/test_grid_128_1.npy
# Doing Fourier Transformation of density field
# Doing Powerspec calculation
# Finished powerspectrum calculation
# Written output to ../examples/testRun_p_outputtest_grid_128_1.dat
