# %%
import matplotlib.pyplot as plt
import numpy as np
from helpers_plot import initPlot, finalizePlot # For pretty plots

# %%
# pip install ../
# Out:
# Processing /home/laila/CodeRepos/BiG
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/laila/miniconda3/envs/bihmcode/lib/python3.12/site-packages (from BiG==0.1.3) (1.26.2)
# Collecting argparse (from BiG==0.1.3)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: pathlib in /home/laila/miniconda3/envs/bihmcode/lib/python3.12/site-packages (from BiG==0.1.3) (1.0.1)
# Requirement already satisfied: jax in /home/laila/miniconda3/envs/bihmcode/lib/python3.12/site-packages (from BiG==0.1.3) (0.4.23)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /home/laila/miniconda3/envs/bihmcode/lib/python3.12/site-packages (from jax->BiG==0.1.3) (0.3.2)
# Requirement already satisfied: opt-einsum in /home/laila/miniconda3/envs/bihmcode/lib/python3.12/site-packages (from jax->BiG==0.1.3) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /home/laila/miniconda3/envs/bihmcode/lib/python3.12/site-packages (from jax->BiG==0.1.3) (1.11.4)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Building wheels for collected packages: BiG
#   Building wheel for BiG (setup.py) ... done
#   Created wheel for BiG: filename=BiG-0.1.3-py3-none-any.whl size=22109 sha256=9554497415f5ff9e0522795ae89d9dd7a2c9c3646696d522fdc734063b969d40
#   Stored in directory: /tmp/pip-ephem-wheel-cache-eb2hllg8/wheels/c1/87/94/f083324098ffff65a492b316de576fcd4676425a2b9e52c662
# Successfully built BiG
# Installing collected packages: argparse, BiG
#   Attempting uninstall: BiG
#     Found existing installation: BiG 0.1.3
#     Uninstalling BiG-0.1.3:
#       Successfully uninstalled BiG-0.1.3
# Successfully installed BiG-0.1.3 argparse-1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Example Running BiG
#
# This notebook runs the Bispectrum extractor on the example set and creates comparison plots to `bskit`.

# %% [markdown]
# ## Run BiG

# %% [markdown]
# First: measure the bispectra in example data. The example data can be downloaded here: https://fileshare.uibk.ac.at/d/6e64b19298ac4e9290f3/. Please place it in the current folder (`examples/`)

# %% [markdown]
# The code reads in the file `testRun_input.dat`, which contains the filepaths to all meshs for which the bispectrum shall be calculated. We also set various binning modes and the output filename

# %%
# Run BiG

# !python ../scripts/runBispectrumExtractor.py --L 1000 --Nmesh 512 --Nkbins 19 --kmin 0.01 --kmax 1.91 --kbinmode lin --mode equilateral --outfn ../examples/testRun_output --infiles ../examples/testRun_input.dat --verbose --doTiming --filetype numpy
# Out:
# Finished reading CMD line arguments
# Settings:
# Boxsize: 1000.0 Mpc/h
# Grid Cells (1D): 512
# ks: [0.01 0.11 0.21 0.31 0.41 0.51 0.61 0.71 0.81 0.91 1.01 1.11 1.21 1.31
#  1.41 1.51 1.61 1.71 1.81]
# Using lin binning
# Triangles: equilateral
# Reading density files from ../examples/testRun_input.dat
# Writing output to ../examples/testRun_output
# Finished setting members of bispectrumExtractor
# Creating k-mesh
# Finished initialization BispectrumExtractor
# Calculating bispectrum for /home/laila/CodeRepos/BiG/examples/test_grid_512_1.npy
#
# Traceback (most recent call last):
#   File "/home/laila/CodeRepos/BiG/examples/../scripts/runBispectrumExtractor.py", line 127, in <module>
#     field_real=loader.load(f)
#                ^^^^^^^^^^^^^^
#   File "/home/laila/miniconda3/envs/bihmcode/lib/python3.12/site-packages/BiG/fileLoader.py", line 11, in load
#     field = np.load(filename)
#             ^^^^^^^^^^^^^^^^^
#   File "/home/laila/miniconda3/envs/bihmcode/lib/python3.12/site-packages/numpy/lib/npyio.py", line 427, in load
#     fid = stack.enter_context(open(os_fspath(file), "rb"))
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/home/laila/CodeRepos/BiG/examples/test_grid_512_1.npy\n'

# %% [markdown]
# ## Load Results

# %% [markdown]
# Second, we load the results from `BSkit` and `BiG` for comparison

# %%
# Load BSKiT Results

bskit_results_1=np.loadtxt("ComparisonDataBSKit/test_grid_512_1_bs_kf_3kf_3lowbins_slow.dat")
bskit_results_2=np.loadtxt("ComparisonDataBSKit/test_grid_512_2_bs_kf_3kf_3lowbins_slow.dat")

bskit_k_1=0.5*(bskit_results_1[:,4]+bskit_results_1[:,5])
bskit_Bk_1=bskit_results_1[:,10]

bskit_k_2=0.5*(bskit_results_2[:,4]+bskit_results_2[:,5])
bskit_Bk_2=bskit_results_2[:,10]

# %%
# Load BiG Results

big_results_1=np.loadtxt("testRun_outputtest_grid_512_1.dat")
big_results_2=np.loadtxt("testRun_outputtest_grid_512_2.dat")

big_k_1=big_results_1[:,0]
big_Bk_1=big_results_1[:,5]

big_k_2=big_results_2[:,0]
big_Bk_2=big_results_2[:,5]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Load BiG Results
# ----> 3 big_results_1=np.loadtxt("testRun_outputtest_grid_512_1.dat")
#       4 big_results_2=np.loadtxt("testRun_outputtest_grid_512_2.dat")
#       6 big_k_1=big_results_1[:,0]
#
# File ~/miniconda3/envs/bihmcode/lib/python3.12/site-packages/numpy/lib/npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# File ~/miniconda3/envs/bihmcode/lib/python3.12/site-packages/numpy/lib/npyio.py:992, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     990     fname = os.fspath(fname)
#     991 if isinstance(fname, str):
# --> 992     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     993     if encoding is None:
#     994         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~/miniconda3/envs/bihmcode/lib/python3.12/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/miniconda3/envs/bihmcode/lib/python3.12/site-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: testRun_outputtest_grid_512_1.dat not found.

# %% [markdown]
# ## Create Plots

# %%
# To make pretty plots
initPlot(labelsize=14, titlesize=14, legendsize=14, usetex=True, fontfamily='sans-serif')

# %%
# Plot 

fig, ax=plt.subplots()
ax.set_title(r"Test Grid 1, Nmesh=$512 \times 512 \times 512$, $L=1000 \mathrm{Mpc}/h$ ")
ax.loglog()
ax.plot(bskit_k_1, np.abs(bskit_Bk_1), ls='-', marker='+', label='BSKit (single-threaded CPU: 152s)')

ax.plot(big_k_1, np.abs(big_Bk_1), ls='--', marker='x', label='BiG (GPU: 3.7s)')
ax.set_xlabel(r"$k [h/\mathrm{Mpc}]$")
ax.set_ylabel(r"$B(k,k,k)$")
finalizePlot(ax, outputFn="Testgrid1.png")

# %%
fig, ax=plt.subplots()
ax.set_title(r"Test Grid 2, Nmesh=$512 \times 512 \times 512$, $L=1000 \mathrm{Mpc}/h$ ")
ax.loglog()
ax.plot(bskit_k_2, np.abs(bskit_Bk_2), ls='-', marker='+', label='BSKit (single-threaded CPU: 159s)')

ax.plot(big_k_2, np.abs(big_Bk_2), ls='--', marker='x', label='BiG (GPU: 3.8s)')
ax.set_xlabel(r"$k [h/\mathrm{Mpc}]$")
ax.set_ylabel(r"$B(k,k,k)$")
finalizePlot(ax, outputFn="Testgrid2.png")
