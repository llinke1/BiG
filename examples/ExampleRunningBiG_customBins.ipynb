# %%
import matplotlib.pyplot as plt
import numpy as np
from helpers_plot import initPlot, finalizePlot # For pretty plots

# %%
# pip install ../

# %% [markdown]
# # Example Running BiG
#
# This notebook runs the Bispectrum extractor on the example set using custom k bins

# %% [markdown]
# ## Run BiG

# %% [markdown]
# The code reads in the file `testRun_input.dat`, which contains the filepaths to all meshs for which the bispectrum shall be calculated. We also set various binning modes and the output filename

# %%
# Run BiG

# !python ../scripts/runBispectrumExtractor_customKbins.py --L 1000 --Nmesh 512 --kbinFile customKBins_bispec.dat --outfn testRun_output_customKs_ --infiles testRun_input.dat --verbose --doTiming --filetype numpy
