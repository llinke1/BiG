# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
import numpy as np

from BiG import plotter as pl

# %%
Plots=pl.plotter()

# %%
data=np.loadtxt("testRun_output_effectiveTriangles_all_test_grid_512_1.dat")

# %%
k_data=data[:,:3]

# %%
kbins=np.linspace(0.01, 1.91, 10)
kbins_lower=kbins[:-1]
kbins_upper=kbins[1:]
kbins_mid=0.5*(kbins_lower+kbins_upper)

ks_low=[]
ks_high=[]

for i in range(9):
    k1_low=kbins_lower[i]
    k1_high=kbins_upper[i]
    for j in range(i,9):
        k2_low=kbins_lower[j]
        k2_high=kbins_upper[j]
        for k in range(j,9):
            k3_low=kbins_lower[k]
            k3_high=kbins_upper[k]
            if kbins_mid[k]<=kbins_mid[i]+kbins_mid[j]:
                ks_low.append([k1_low, k2_low, k3_low])
                ks_high.append([k1_high, k2_high, k3_high])

ks_low=np.array(ks_low)
ks_high=np.array(ks_high)

# %%
Plots.addBispectrum(ks=data[:,:3], kbinedges_low=ks_low, kbinedges_high=ks_high, bispec=data[:,8], name='1')

# %%
Plots.addBispectrum(ks=data[:,:3], kbinedges_low=ks_low, kbinedges_high=ks_high, bispec=data[:,8], name='2')

# %%
Plots.plotBispectrum3D(names=['1'])
# Out:
# /home/laila/miniconda3/envs/nbodykit-env/lib/python3.8/site-packages/mpl_toolkits/mplot3d/art3d.py:794: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if zdir == 'x':
# /home/laila/miniconda3/envs/nbodykit-env/lib/python3.8/site-packages/mpl_toolkits/mplot3d/art3d.py:796: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif zdir == 'y':

# %%
Plots.plotBispectrum3D(names=['1', '2'])
# Out:
# /home/laila/miniconda3/envs/nbodykit-env/lib/python3.8/site-packages/mpl_toolkits/mplot3d/art3d.py:794: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if zdir == 'x':
# /home/laila/miniconda3/envs/nbodykit-env/lib/python3.8/site-packages/mpl_toolkits/mplot3d/art3d.py:796: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif zdir == 'y':

# %%
Plots.plotBispectrum1D(k1_k3=0.5, k2_k3=1.)
# Out:
# /home/laila/CodeRepos/BiG/tests/helpers_plot.py:72: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
Plots.plotBispectrum1D(k1_k3=0.5, k2_k3=1., names=['1'])
# Out:
# /home/laila/CodeRepos/BiG/tests/helpers_plot.py:72: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
Plots.plotBispectrumTriangle(1, names=['1'])

# %%
Plots.plotBispectrumTriangle(1, names=['1', '2'])
